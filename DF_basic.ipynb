# %% [markdown]
# # Pandas DataFrame Intro
#
# This notebook demonstrates how to work with a Pandas DataFrame.
# We will:
#
# - Load data from `data/symbol_info_3-25.csv` file, randomly sampling 25 rows, and selecting the desired columns.
# - Display general information about the DataFrame.
# - Show the content by position and by column
# - Sort the DataFrame by `Market_cap`.
# - Add a column with the percentage of each `Market_cap` relative to the total market cap.
# - Grouping and aggregation
# - Advanced Sorting and indexing
# - Filtering
# - Operations on non-numerical columns

# %% [markdown]
# ## Loading and Sampling Data
#
# We start by loading a CSV file into a DataFrame, then randomly selecting 25 rows and keeping only the columns we need: `symbol`, `market_cap`, and `sector`.

# %%
# Install pandas if it is not already available in this notebook environment
# %pip install pandas

# Import the pandas library (the main tool for working with tabular data in Python)
import pandas as pd

# Load all data from the CSV file into a DataFrame
df = pd.read_csv('data/symbol_info_3-25.csv')

# Randomly pick 25 rows from the full dataset
# random_state=42 ensures we always get the same 25 rows (for reproducibility)
#I change random_state, I replace 42 with 99
df_sample = df.sample(25, random_state=99)

# Keep only the 3 columns we need
df_sample = df_sample[['symbol', 'market_cap', 'sector','enterprise_value' ]]

# Display the result
print('--- Initial Sampled DataFrame ---')
print(df_sample)
# Out:
# Requirement already satisfied: pandas in c:\users\alfre\appdata\local\programs\python\python313\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alfre\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alfre\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\alfre\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in c:\users\alfre\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# --- Initial Sampled DataFrame ---
#     symbol    market_cap                  sector      enterprise_value
# 890    CFR    7877785600      Financial Services            2650020352
# 983   MTDR    6549599232                  Energy           10252836864
# 107     TD  104969248768      Financial Services  18446744035028250624
# 609   DLTR   14353853440      Consumer Defensive           24205928448
# 113    ICE  100887920640      Financial Services          120167366656
# 350   HUBS   31618861056              Technology           30294767616
# 22     JNJ  394323787776              Healthcare          407270326272
# 136   EQIX   82899656704             Real Estate           97136320512
# 674   AKAM   12258435072              Technology           15219755008
# 46       T  193954430976  Communication Services          352347521024
# 436    FOX   23234004992  Communication Services           27651364864
# 437   FOXA   23231510528  Communication Services           29329047552
# 813    FND    9040594944       Consumer Cyclical           10539431936
# 271    AMX   43434962944  Communication Services         1615049916416
# 563    CNH   16161944576             Industrials           40541736960
# 214    ALL   55703130112      Financial Services           59725926400
# 630   DUOL   13852433408              Technology           13171703808
# 294   LULU   39512559616       Consumer Cyclical           39615483904
# 245   COIN   48333611008      Financial Services           44287229952
# 746   PCOR   10551650304              Technology            9856293888
# 435    DRI   23421198336       Consumer Cyclical           31039795200
# 455    IOT   22161735680              Technology           22023391232
# 954    ONB    6822923264      Financial Services           11474241536
# 109    APP  104056668160              Technology          109572079616
# 50     PDD  181818310656       Consumer Cyclical          382757339136
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Exploring the DataFrame
#
# Before working with data, it is important to understand its structure. We use:
#
# - **`.info()`** — shows column names, data types, and non-null counts
# - **`.describe()`** — gives summary statistics for numerical columns (mean, std, min, max, quartiles)
# - **`.describe(include='str')`** — gives summary statistics for text columns (count, unique values, most frequent)

# %%
# .info() prints a summary: column names, types, and how many non-null values
print('--- DataFrame Info ---')
df_sample.info()

# .describe() gives statistics for numerical columns (count, mean, std, min, max, quartiles)
print('\n--- DataFrame Description (numerical columns) ---')
print(df_sample.describe())

# .describe(include='str') gives statistics for text columns (count, unique values, most frequent)
print('\n--- DataFrame Description (text columns) ---')
print(df_sample.describe(include='str'))
# Out:
# --- DataFrame Info ---
# <class 'pandas.DataFrame'>
# Index: 25 entries, 890 to 50
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symbol            25 non-null     str
#  1   market_cap        25 non-null     int64
#  2   sector            25 non-null     str
#  3   enterprise_value  25 non-null     uint64
# dtypes: int64(1), str(2), uint64(1)
# memory usage: 1000.0 bytes
#
# --- DataFrame Description (numerical columns) ---
#          market_cap  enterprise_value
# count  2.500000e+01      2.500000e+01
# mean   6.284123e+10      7.378699e+17
# std    8.648188e+10      3.689349e+18
# min    6.549599e+09      2.650020e+09
# 25%    1.385243e+10      1.521976e+10
# 50%    2.342120e+10      3.103980e+10
# 75%    8.289966e+10      1.095721e+11
# max    3.943238e+11      1.844674e+19
#
# --- DataFrame Description (text columns) ---
#        symbol              sector
# count      25                  25
# unique     25                   9
# top       CFR  Financial Services
# freq        1                   6

# %% [markdown]
# ## Accessing Rows by Position with `.iloc[]`
#
# `.iloc[]` lets you select rows by their **position** (like indexing a Python list). Position `0` is the first row, `-1` is the last, `-2` is the second-to-last, and so on.

# %%
# .iloc[] lets you access rows by their POSITION (like a list index)

# First row (position 0)
print('--- First Element (iloc[0]) ---')
print(df_sample.iloc[0])

# Access a specific column value from the first row
print('\n--- Market Cap of the first Element ---')
print(df_sample.iloc[0]['market_cap'])

# Last row (position -1, just like Python lists)
print('\n--- Last Element (iloc[-1]) ---')
print(df_sample.iloc[-1])

# Second-to-last row
print('\n--- Second-to-Last Element (iloc[-2]) ---')
print(df_sample.iloc[-2])
# Out:
# --- First Element (iloc[0]) ---
# symbol                             CFR
# market_cap                  7877785600
# sector              Financial Services
# enterprise_value            2650020352
# Name: 890, dtype: object
#
# --- Market Cap of the first Element ---
# 7877785600
#
# --- Last Element (iloc[-1]) ---
# symbol                            PDD
# market_cap               181818310656
# sector              Consumer Cyclical
# enterprise_value         382757339136
# Name: 50, dtype: object
#
# --- Second-to-Last Element (iloc[-2]) ---
# symbol                       APP
# market_cap          104056668160
# sector                Technology
# enterprise_value    109572079616
# Name: 109, dtype: object

# %% [markdown]
# ## Sorting a DataFrame
#
# We can sort the rows of a DataFrame by any column using `.sort_values()`. Here we sort by `market_cap` in descending order (largest first).

# %%
# Sort the DataFrame by Market_cap
df_sorted = df_sample.sort_values(by='market_cap', ascending=False)
print('--- DataFrame Sorted by Market_cap ---')
print(df_sorted)
# Out:
# --- DataFrame Sorted by Market_cap ---
#     symbol    market_cap                  sector      enterprise_value
# 22     JNJ  394323787776              Healthcare          407270326272
# 46       T  193954430976  Communication Services          352347521024
# 50     PDD  181818310656       Consumer Cyclical          382757339136
# 107     TD  104969248768      Financial Services  18446744035028250624
# 109    APP  104056668160              Technology          109572079616
# 113    ICE  100887920640      Financial Services          120167366656
# 136   EQIX   82899656704             Real Estate           97136320512
# 214    ALL   55703130112      Financial Services           59725926400
# 245   COIN   48333611008      Financial Services           44287229952
# 271    AMX   43434962944  Communication Services         1615049916416
# 294   LULU   39512559616       Consumer Cyclical           39615483904
# 350   HUBS   31618861056              Technology           30294767616
# 435    DRI   23421198336       Consumer Cyclical           31039795200
# 436    FOX   23234004992  Communication Services           27651364864
# 437   FOXA   23231510528  Communication Services           29329047552
# 455    IOT   22161735680              Technology           22023391232
# 563    CNH   16161944576             Industrials           40541736960
# 609   DLTR   14353853440      Consumer Defensive           24205928448
# 630   DUOL   13852433408              Technology           13171703808
# 674   AKAM   12258435072              Technology           15219755008
# 746   PCOR   10551650304              Technology            9856293888
# 813    FND    9040594944       Consumer Cyclical           10539431936
# 890    CFR    7877785600      Financial Services            2650020352
# 954    ONB    6822923264      Financial Services           11474241536
# 983   MTDR    6549599232                  Energy           10252836864

# %% [markdown]
# ## Operations on a Numerical Column
#
# Pandas provides many built-in functions to summarize a numerical column. Here are the most common ones applied to `market_cap`:
#
# | Function | What it does |
# |----------|-------------|
# | `.sum()` | Total of all values |
# | `.mean()` | Average (sum / count) |
# | `.median()` | Middle value when sorted |
# | `.min()` / `.max()` | Smallest / largest value |
# | `.std()` | Standard deviation (how spread out the values are) |
# | `.var()` | Variance (square of std) |
# | `.quantile([0.25, 0.5, 0.75])` | Values at the 25th, 50th, 75th percentiles |
#
# **Example usage:**
# ```python
# total_market_cap = df_sample['market_cap'].sum()
# average_market_cap = df_sample['market_cap'].mean()
# ```

# %% [markdown]
# ## Adding a Computed Column
#
# We can create a new column based on existing data. Here we compute the **percentage** that each company's market cap represents out of the total market cap of all 25 companies.

# %%
# --- Add a new column: percentage of total market cap ---

# First, compute the total market cap across all 25 companies
#total_market_cap = df_sample['market_cap'].sum()

# Divide each company's market_cap by the total and multiply by 100 to get a percentage
#df_sample['market_cap_%'] = (df_sample['market_cap'] / total_market_cap) * 100

#print('--- DataFrame with Market Cap Percentage ---')
#print(df_sample)

#as exercise, we compute the mean
mean_enterprise_value = df_sample['enterprise_value'].mean()

#Still as part of the exercise, we compute the difference between the each value and the mean
df_sample['difference'] = df_sample['enterprise_value'] - mean_enterprise_value

pd.set_option('display.expand_frame_repr', False) #Prevents the output from wrapping to a new line

#I print this to show the results
print('--- DataFrame with the difference ---')
print(df_sample)




# --- Alternative ways to do the same thing (commented out for reference) ---

# Using apply() with a lambda (a one-line anonymous function):
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(lambda x: (x / total_market_cap) * 100)

# Using apply() with a named function:
# def compute_percentage(value):
#     return (value / total_market_cap) * 100
# df_sample['market_cap_%'] = df_sample['market_cap'].apply(compute_percentage)
# Out:
# --- DataFrame with the difference ---
#     symbol    market_cap                  sector      enterprise_value    difference
# 890    CFR    7877785600      Financial Services            2650020352 -7.378699e+17
# 983   MTDR    6549599232                  Energy           10252836864 -7.378699e+17
# 107     TD  104969248768      Financial Services  18446744035028250624  1.770887e+19
# 609   DLTR   14353853440      Consumer Defensive           24205928448 -7.378699e+17
# 113    ICE  100887920640      Financial Services          120167366656 -7.378698e+17
# 350   HUBS   31618861056              Technology           30294767616 -7.378699e+17
# 22     JNJ  394323787776              Healthcare          407270326272 -7.378695e+17
# 136   EQIX   82899656704             Real Estate           97136320512 -7.378698e+17
# 674   AKAM   12258435072              Technology           15219755008 -7.378699e+17
# 46       T  193954430976  Communication Services          352347521024 -7.378695e+17
# 436    FOX   23234004992  Communication Services           27651364864 -7.378699e+17
# 437   FOXA   23231510528  Communication Services           29329047552 -7.378699e+17
# 813    FND    9040594944       Consumer Cyclical           10539431936 -7.378699e+17
# 271    AMX   43434962944  Communication Services         1615049916416 -7.378683e+17
# 563    CNH   16161944576             Industrials           40541736960 -7.378699e+17
# 214    ALL   55703130112      Financial Services           59725926400 -7.378698e+17
# 630   DUOL   13852433408              Technology           13171703808 -7.378699e+17
# 294   LULU   39512559616       Consumer Cyclical           39615483904 -7.378699e+17
# 245   COIN   48333611008      Financial Services           44287229952 -7.378699e+17
# 746   PCOR   10551650304              Technology            9856293888 -7.378699e+17
# 435    DRI   23421198336       Consumer Cyclical           31039795200 -7.378699e+17
# 455    IOT   22161735680              Technology           22023391232 -7.378699e+17
# 954    ONB    6822923264      Financial Services           11474241536 -7.378699e+17
# 109    APP  104056668160              Technology          109572079616 -7.378698e+17
# 50     PDD  181818310656       Consumer Cyclical          382757339136 -7.378695e+17

# %% [markdown]
# ## Grouping and Aggregation
#
# Sometimes we want to **summarize data by category**. For example: *"What is the total market cap for each sector?"*
#
# The idea is simple — split the data into groups (one per sector), then compute a summary for each group.
#
# We do this in three steps:
#
# 1. **Group** the rows by a column (e.g., `sector`) using `groupby()`
# 2. **Pick** the column we want to summarize (e.g., `market_cap`)
# 3. **Apply** one or more summary functions (`sum`, `mean`, `count`)

# %%
# Step 1: Group the rows by 'sector'
grouped = df_sample.groupby('sector')
print('Step 1 — type:', type(grouped).__name__)
print('Number of groups:', grouped.ngroups)
print('Group sizes:')
print(grouped.size())
print()

# Let's peek inside one group to see what it looks like
print('--- Example: the "Technology" group ---')
print(grouped.get_group('Technology'))
print()

# Step 2: Select the 'market_cap' column from each group
market_cap_by_sector = grouped['market_cap']
print('Step 2 — now we only keep the market_cap values per group:')
for name, values in market_cap_by_sector:
    print(f'  {name}: {values.tolist()}')
print()

# Step 3: Apply summary functions — sum, mean, and count
df_grouped = market_cap_by_sector.agg(['sum', 'mean', 'count'])
print('Step 3 — after agg():')
print(df_grouped)
print()
# Notice: 'sector' is now the index, not a regular column

# reset_index() turns 'sector' back into a regular column
df_grouped = df_grouped.reset_index()
print('After reset_index():')
print(df_grouped)

# NOTE: The 4 steps above can also be written in one line:
# df_grouped = df_sample.groupby('sector')['market_cap'].agg(['sum', 'mean', 'count']).reset_index()
# Out:
# Step 1 — type: DataFrameGroupBy
# Number of groups: 9
# Group sizes:
# sector
# Communication Services    4
# Consumer Cyclical         4
# Consumer Defensive        1
# Energy                    1
# Financial Services        6
# Healthcare                1
# Industrials               1
# Real Estate               1
# Technology                6
# dtype: int64
#
# --- Example: the "Technology" group ---
#     symbol    market_cap      sector  enterprise_value    difference
# 350   HUBS   31618861056  Technology       30294767616 -7.378699e+17
# 674   AKAM   12258435072  Technology       15219755008 -7.378699e+17
# 630   DUOL   13852433408  Technology       13171703808 -7.378699e+17
# 746   PCOR   10551650304  Technology        9856293888 -7.378699e+17
# 455    IOT   22161735680  Technology       22023391232 -7.378699e+17
# 109    APP  104056668160  Technology      109572079616 -7.378698e+17
#
# Step 2 — now we only keep the market_cap values per group:
#   Communication Services: [193954430976, 23234004992, 23231510528, 43434962944]
#   Consumer Cyclical: [9040594944, 39512559616, 23421198336, 181818310656]
#   Consumer Defensive: [14353853440]
#   Energy: [6549599232]
#   Financial Services: [7877785600, 104969248768, 100887920640, 55703130112, 48333611008, 6822923264]
#   Healthcare: [394323787776]
#   Industrials: [16161944576]
#   Real Estate: [82899656704]
#   Technology: [31618861056, 12258435072, 13852433408, 10551650304, 22161735680, 104056668160]
#
# Step 3 — after agg():
#                                  sum          mean  count
# sector
# Communication Services  283854909440  7.096373e+10      4
# Consumer Cyclical       253792663552  6.344817e+10      4
# Consumer Defensive       14353853440  1.435385e+10      1
# Energy                    6549599232  6.549599e+09      1
# Financial Services      324594619392  5.409910e+10      6
# Healthcare              394323787776  3.943238e+11      1
# Industrials              16161944576  1.616194e+10      1
# Real Estate              82899656704  8.289966e+10      1
# Technology              194499783680  3.241663e+10      6
#
# After reset_index():
#                    sector           sum          mean  count
# 0  Communication Services  283854909440  7.096373e+10      4
# 1       Consumer Cyclical  253792663552  6.344817e+10      4
# 2      Consumer Defensive   14353853440  1.435385e+10      1
# 3                  Energy    6549599232  6.549599e+09      1
# 4      Financial Services  324594619392  5.409910e+10      6
# 5              Healthcare  394323787776  3.943238e+11      1
# 6             Industrials   16161944576  1.616194e+10      1
# 7             Real Estate   82899656704  8.289966e+10      1
# 8              Technology  194499783680  3.241663e+10      6

# %% [markdown]
# ## Advanced Sorting and Indexing
#
# By default, a DataFrame uses row numbers (0, 1, 2, ...) as its index. But we can change the index to something more meaningful:
#
# - **`set_index('symbol')`** — use the stock symbol as the row label, so we can look up rows by name (e.g., `df.loc['PYPL']`)
# - **Multi-index** — use *two* columns as a combined index (e.g., `sector` + `symbol`), which organizes the data hierarchically
# - **Sorting by multiple columns** — for example, sort by `sector` alphabetically, and within each sector sort by `market_cap` from largest to smallest

# %%
# --- Using set_index() ---
# Replace the default numeric index with 'symbol', so each row is labeled by its stock ticker
df_indexed = df_sample.set_index('symbol')
print('--- DataFrame with symbol as index ---')
print(df_indexed)

# --- Multi-Index ---
# Use TWO columns as the index: first 'sector', then 'symbol'
# This creates a hierarchical structure: sector > symbol
df_multi_indexed = df_sample.set_index(['sector', 'symbol'])
print('\n--- DataFrame with Multi-Index (sector, symbol) ---')
print(df_multi_indexed)

# --- Sorting by multiple columns ---
# Sort by 'sector' A→Z (ascending=True), then within each sector
# sort by 'market_cap' from largest to smallest (ascending=False)
df_sorted_multi = df_sample.sort_values(
    by=['sector', 'market_cap'],
    ascending=[True, False]
)
print('\n--- DataFrame sorted by sector (A-Z) and market_cap (largest first) ---')
print(df_sorted_multi)
# Out:
# --- DataFrame with symbol as index ---
#           market_cap                  sector      enterprise_value    difference
# symbol
# CFR       7877785600      Financial Services            2650020352 -7.378699e+17
# MTDR      6549599232                  Energy           10252836864 -7.378699e+17
# TD      104969248768      Financial Services  18446744035028250624  1.770887e+19
# DLTR     14353853440      Consumer Defensive           24205928448 -7.378699e+17
# ICE     100887920640      Financial Services          120167366656 -7.378698e+17
# HUBS     31618861056              Technology           30294767616 -7.378699e+17
# JNJ     394323787776              Healthcare          407270326272 -7.378695e+17
# EQIX     82899656704             Real Estate           97136320512 -7.378698e+17
# AKAM     12258435072              Technology           15219755008 -7.378699e+17
# T       193954430976  Communication Services          352347521024 -7.378695e+17
# FOX      23234004992  Communication Services           27651364864 -7.378699e+17
# FOXA     23231510528  Communication Services           29329047552 -7.378699e+17
# FND       9040594944       Consumer Cyclical           10539431936 -7.378699e+17
# AMX      43434962944  Communication Services         1615049916416 -7.378683e+17
# CNH      16161944576             Industrials           40541736960 -7.378699e+17
# ALL      55703130112      Financial Services           59725926400 -7.378698e+17
# DUOL     13852433408              Technology           13171703808 -7.378699e+17
# LULU     39512559616       Consumer Cyclical           39615483904 -7.378699e+17
# COIN     48333611008      Financial Services           44287229952 -7.378699e+17
# PCOR     10551650304              Technology            9856293888 -7.378699e+17
# DRI      23421198336       Consumer Cyclical           31039795200 -7.378699e+17
# IOT      22161735680              Technology           22023391232 -7.378699e+17
# ONB       6822923264      Financial Services           11474241536 -7.378699e+17
# APP     104056668160              Technology          109572079616 -7.378698e+17
# PDD     181818310656       Consumer Cyclical          382757339136 -7.378695e+17
#
# --- DataFrame with Multi-Index (sector, symbol) ---
#                                  market_cap      enterprise_value    difference
# sector                 symbol
# Financial Services     CFR       7877785600            2650020352 -7.378699e+17
# Energy                 MTDR      6549599232           10252836864 -7.378699e+17
# Financial Services     TD      104969248768  18446744035028250624  1.770887e+19
# Consumer Defensive     DLTR     14353853440           24205928448 -7.378699e+17
# Financial Services     ICE     100887920640          120167366656 -7.378698e+17
# Technology             HUBS     31618861056           30294767616 -7.378699e+17
# Healthcare             JNJ     394323787776          407270326272 -7.378695e+17
# Real Estate            EQIX     82899656704           97136320512 -7.378698e+17
# Technology             AKAM     12258435072           15219755008 -7.378699e+17
# 1. A **condition** like `df['market_cap'] > 100` produces a column of `True`/`False` values (called a **boolean mask**)
# 2. We can combine multiple conditions with `&` (AND) or `|` (OR)
# 3. Passing the mask inside `df[...]` keeps only the rows where the result is `True`

# %%
# First, compute the average market_cap (we need this as our threshold)
average_market_cap = df_sample['market_cap'].mean()
print(f'Average market cap: {average_market_cap:,.0f}')

# Condition 1: market_cap is above average
above_average = df_sample['market_cap'] > average_market_cap

# Condition 2: sector is either "Technology" or "Financial Services"
# isin() checks if each value is in the given list
selected_sectors = df_sample['sector'].isin(['Technology', 'Financial Services'])

# Combine both conditions with & (AND) — both must be True
condition = above_average & selected_sectors

# Apply the filter: keep only rows where condition is True
df_filtered = df_sample[condition]

print('\n--- Filtered: market_cap > average AND sector is Technology or Financial Services ---')
print(df_filtered)
# Out:
# Average market cap: 62,841,232,712
#
# --- Filtered: market_cap > average AND sector is Technology or Financial Services ---
#     symbol    market_cap              sector      enterprise_value    difference
# 107     TD  104969248768  Financial Services  18446744035028250624  1.770887e+19
# 113    ICE  100887920640  Financial Services          120167366656 -7.378698e+17
# 109    APP  104056668160          Technology          109572079616 -7.378698e+17

# %% [markdown]
# ## Operations on Text (String) Columns
#
# Pandas provides string methods via `.str` to work with text data. In this section we will:
#
# - Get the **unique values** in a column and count how often each appears
# - **Convert** text to uppercase
# - **Search** for rows containing a specific word
# - **Replace** specific values with new ones
# - **Map** values to a simplified version using a dictionary

# %%
# --- Getting unique values ---
unique_sectors = df_sample['sector'].unique()
print('--- Unique Sectors ---')
print(unique_sectors)

# --- Counting occurrences ---
# How many companies are in each sector?
sector_counts = df_sample['sector'].value_counts()
print('\n--- Count of Each Sector ---')
print(sector_counts)

# --- Converting text to uppercase ---
# .str gives access to string methods on a whole column
df_sample['sector_upper'] = df_sample['sector'].str.upper()
print('\n--- DataFrame with uppercase sector column added ---')
print(df_sample)

# --- Searching for text inside a column ---
# Find all rows where 'sector' contains the word "tech" (case-insensitive)
df_tech = df_sample[df_sample['sector'].str.contains('tech', case=False, na=False)]
print('\n--- Rows where sector contains "tech" ---')
print(df_tech)

# --- Replacing specific values ---
# Change "Financial Services" to "Finance" everywhere in the column
df_sample['sector_replaced'] = df_sample['sector'].replace({'Financial Services': 'Finance'})
print('\n--- DataFrame with "Financial Services" replaced by "Finance" ---')
print(df_sample)

# --- Mapping values using a dictionary ---
# map() replaces values that match a key; non-matching values become NaN
sector_mapping = {
    'Technology': 'Tech',
    'Financial Services': 'Finance',
    'Industrials': 'Industrial'
}
df_sample['sector_mapped'] = df_sample['sector'].map(sector_mapping)
print('\n--- DataFrame with mapped sector names (unmatched sectors become NaN) ---')
print(df_sample)
# Out:
# --- Unique Sectors ---
# <StringArray>
# [    'Financial Services',                 'Energy',     'Consumer Defensive',
#              'Technology',             'Healthcare',            'Real Estate',
#  'Communication Services',      'Consumer Cyclical',            'Industrials']
# Length: 9, dtype: str
#
